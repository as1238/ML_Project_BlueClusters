# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.84-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.84

# %%
# Import Drive API and authenticate.
from google.colab import drive
# Mount your Drive to the Colab VM.
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from sklearn.model_selection import TimeSeriesSplit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

import random,os
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, TensorDataset, DataLoader, Subset
from collections import OrderedDict


from sklearn.preprocessing import MinMaxScaler

device = 'cuda' if torch.cuda.is_available() else 'cpu'
overall=dict()

# Load the stock price or the blockchain or the json, (good to have api call for and load the json) let's choose ETH--Aider
# Import Drive API and authenticate.
# from google.colab import drive
# # Mount your Drive to the Colab VM.
# drive.mount('/content/gdrive')

def build_df(path_to_parquet_file, array_with_our_choices):

  # reading the big df with all assets
  all_assets = pd.DataFrame()
  all_assets = pd.read_parquet(path_to_parquet_file)

  # resetting index and cleaning column names from bull shit
  all_assets.reset_index(inplace=True)
  all_assets.columns = [c.split('.')[-1].replace('_','') for c in all_assets.columns]

  # array with all unqiue symbols from MAIN FILE
  all_symbols = all_assets["symbol"].unique()

  # list to store our small dataframes with our chosen assets
  list_of_df = list()

# just in case, this is very important --> below is for loop haha

  for symbol in array_with_our_choices:

    # temp df for slicing main big df
    temp_df = pd.DataFrame()
    temp_df = all_assets.loc[all_assets['symbol'] == symbol]

    # small df for processing stuff and storing in our list_of_df
    small_df = pd.DataFrame()
    small_df = temp_df[['timeclose', 'close', 'marketcap', 'volume']]
    small_df['timeclose'] = pd.to_datetime(small_df['timeclose'])

    small_df = small_df.set_index(['timeclose'])

    # inserting column for "returns"
    small_df.insert(1, 'returns', small_df['close'].pct_change())
    small_df = small_df.rename(columns={'close' : 'price'})

    # renaming columns based on the symbol that we are looping at
    small_df.columns = [c.replace(c, symbol+'_'+c) for c in small_df.columns]

    # pasting to our list
    list_of_df.append(small_df)

  # final dataframe with beatufilly structured chosen assets
  final_df = pd.DataFrame()

  # looping thru our chosen assets in our list
  for df in list_of_df:
    final_df = final_df.join(df, how='outer')


  return final_df

# %%
# path_to_file = 'hourly.parquet.gzip'
path_to_file = '/content/gdrive/My Drive/ML540 - Blue Clusters/datafiles/hourly.parquet.gzip'

# LIST HERE WHAT ASSETS WE WANT TO WORK WITH. HERE IS JUST AN EXAMPLE OF 3 ASSETS TO TEST FUNCTION
our_choices = ['ETH']

# new final df
df = build_df(path_to_file, our_choices)
df.head()
# printing our FINAL TEST_DF
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    ETH_price  ETH_returns  ETH_marketcap  \
# timeclose
# 2019-01-01 20:59:59.999000+00:00  140.346549          NaN   1.461575e+10
# 2019-01-01 21:59:59.999000+00:00  139.695956    -0.004636   1.454810e+10
# 2019-01-01 22:59:59.999000+00:00  139.968871     0.001954   1.457664e+10
# 2019-01-01 23:59:59.999000+00:00  140.819413     0.006077   1.466532e+10
# 2019-01-02 00:59:59.999000+00:00  141.995471     0.008352   1.478792e+10
#
#                                   ETH_volume
# timeclose
# 2019-01-01 20:59:59.999000+00:00         NaN
# 2019-01-01 21:59:59.999000+00:00         NaN
# 2019-01-01 22:59:59.999000+00:00         NaN
# 2019-01-01 23:59:59.999000+00:00         NaN
# 2019-01-02 00:59:59.999000+00:00         NaN

# %%
#EDA plot the graph and transfer the data in the certain format . date(index)...price... seperate the dataset to training set and test set(might need the cross-validation)--Adri--
# fig, ax = plt.subplots()
# prices = df['ETH_price'].values.reshape(-1, 1)
#
# ax.plot(df.index, prices)
# ax.set(title=f"{our_choices[0]}'s price",
#        xlabel='Time',
#        ylabel='Price ($)');
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(df['ETH_price'], model = 'multiplicative', period=365)
plt.rcParams['figure.figsize'] = [15,15]
decomposition.plot()
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(df['ETH_price'], model = 'additive',period=365)
plt.rcParams['figure.figsize'] = [12, 12]
decomposition.plot()
plt.show()

# %%
def splitData(df, train_percent):
  min_date = df.index.min()
  max_date = df.index.max()
  time_between = max_date - min_date
  train_cutoff = min_date + train_percent*time_between
  train_cutoff
  train_df = df[df.index <= train_cutoff]
  test_df = df[df.index > train_cutoff]
  return train_df, test_df

# %%
df['ds'] = df.index.tz_convert(None)
df['y'] = df['ETH_price']
df['add1'] = df['ETH_marketcap'].shift(1)
df.dropna(subset=['add1'],inplace=True)
train_df, test_df=splitData(df,0.9)
display(df.head()) 
print("Train:", train_df.index.min(), train_df.index.max())
print("Test:", test_df.index.min(), test_df.index.max())
# Out:
#                                    ETH_price  ETH_returns  ETH_marketcap  \
# timeclose
# 2019-01-01 22:59:59.999000+00:00  139.968871     0.001954   1.457664e+10
# 2019-01-01 23:59:59.999000+00:00  140.819413     0.006077   1.466532e+10
# 2019-01-02 00:59:59.999000+00:00  141.995471     0.008352   1.478792e+10
# 2019-01-02 01:59:59.999000+00:00  141.125948    -0.006124   1.469747e+10
# 2019-01-02 02:59:59.999000+00:00  141.074109    -0.000367   1.469218e+10
#
#                                   ETH_volume                      ds  \
# timeclose
# 2019-01-01 22:59:59.999000+00:00         NaN 2019-01-01 22:59:59.999
# 2019-01-01 23:59:59.999000+00:00         NaN 2019-01-01 23:59:59.999
# 2019-01-02 00:59:59.999000+00:00         NaN 2019-01-02 00:59:59.999
# 2019-01-02 01:59:59.999000+00:00         NaN 2019-01-02 01:59:59.999
# 2019-01-02 02:59:59.999000+00:00         NaN 2019-01-02 02:59:59.999
#
#                                            y          add1
# timeclose
# 2019-01-01 22:59:59.999000+00:00  139.968871  1.454810e+10
# 2019-01-01 23:59:59.999000+00:00  140.819413  1.457664e+10
# 2019-01-02 00:59:59.999000+00:00  141.995471  1.466532e+10
# 2019-01-02 01:59:59.999000+00:00  141.125948  1.478792e+10
# 2019-01-02 02:59:59.999000+00:00  141.074109  1.469747e+10
# Train: 2019-01-01 22:59:59.999000+00:00 2022-05-26 00:59:59.999000+00:00
# Test: 2022-05-26 01:59:59.999000+00:00 2022-10-10 19:59:59.999000+00:00

# %%
from sklearn.linear_model import LinearRegression


#Regression model there are two way to do it. ( shift the datetime )--sinuo
def autocorr_model(eth_df, days_lag):

    ### BEGIN SOLUTION ###

    # Add column containing the value at t-1
    eth_df['PreETH_price'] = eth_df['ETH_price'].shift() #Add new column containing count at days_lag
    eth_df = eth_df.iloc[days_lag:]

    # Create a single-variable linear regression
    model = LinearRegression()
    model.fit(X=eth_df['PreETH_price'].values.reshape(-1, 1), y=eth_df['ETH_price'])

    # Get in-sample predictions for the days in the month
    preds = model.predict(eth_df['PreETH_price'].values.reshape(-1, 1))
    resids = eth_df['ETH_price'] - preds

    return model, preds, resids

# %%
regressionData = train_df.copy()

days_lag = 1
model, preds, resids = autocorr_model(regressionData,days_lag)

# Display the model
print('The training model is: y = {:.3f}x + {:.3f}'.format(model.coef_[0], model.intercept_))
mse = np.sum(abs(resids),axis=0)/len(resids)
r2 = 1 - mse/np.var(regressionData['ETH_price'][days_lag:])
# Calculate and display the model performance statistics

overall['linear_regression_autocorr']={'train': {'mae':mse,"r2":r2}}
print('The simple linear model has R^2={:.3f} and MAE={:.2f}'.format(r2,mse))
# Plot the data and the predictions
plt.figure(figsize=(15,10))
plt.scatter(x=regressionData.index, y=regressionData['ETH_price'])
plt.plot(regressionData.index[days_lag:], preds,color='red')
plt.xlim((regressionData.index[days_lag:].min(),regressionData.index[days_lag:].max()))
plt.ylabel('Training dateset for ETH Price')
plt.show()
# Out:
# The training model is: y = 1.000x + 0.193
# The simple linear model has R^2=1.000 and MAE=8.01

# %%
from sklearn.metrics import r2_score,mean_absolute_error
regressionData = test_df.copy()
regressionData['PreETH_price'] = regressionData['ETH_price'].shift()
regressionData = regressionData.iloc[1:]
preds = model.predict(regressionData['PreETH_price'].values.reshape(-1, 1))

r2_auto = r2_score(regressionData['ETH_price'], preds)
mae_auto = mean_absolute_error(regressionData['ETH_price'], preds)
print('The simple linear model has R^2={:.3f},MAE={:.2f}'.format(r2_auto, mae_auto))

overall['linear_regression_autocorr']['test']={'mae':mae_auto,"r2":r2_auto}

# Plot the data and the predictions
plt.figure(figsize=(15,10))
plt.scatter(x=regressionData.index, y=regressionData['ETH_price'])
plt.plot(regressionData.index, preds,color='red')
plt.xlim((regressionData.index[days_lag:].min(),regressionData.index[days_lag:].max()))
plt.ylabel('Test dateset for ETH Price')
plt.show()
# Out:
# The simple linear model has R^2=0.997,MAE=8.92

# %%
#Regression model there are two way to do it. (1. deal with the dummy datetime date )
def model_trend_seasonality(df_trending):
    '''
    Performs linear regression incorporating both trend (using days passed as a feature) and weekly seasonality (using day of week)

    Inputs:
        flights_per_day(pd.Series): series containing the count of flights per day, with date as the index

    Returns:
        model(sklearn.linear_model.LinearRegression()): trained linear regression model
        preds(np.ndarray): array containing the in-sample predictions
        resids(np.ndarray): array containing the errors of the in-sample predictions
    '''

    ### BEGIN SOLUTION ###

    df_trending['Day_of_hour'] = df_trending.index.hour

    fullmodel_encoded = pd.get_dummies(data = df_trending, columns=['Day_of_hour'])
    fullmodel_encoded['Days'] = (fullmodel_encoded.index-fullmodel_encoded.index.min()).days
    fullmodel_encoded['ETH_marketcap'] = fullmodel_encoded['ETH_marketcap'].shift()

    # Create a linear regression and fit it to the data
    model = LinearRegression()
    X = fullmodel_encoded.drop(['ETH_price', 'ETH_volume','ds','y','add1','ETH_returns'],axis=1).iloc[1:]
    display(X.head())

    y = fullmodel_encoded['ETH_price'].iloc[1:]
    model.fit(X, y)

    # Get in-sample predictions (on the training set)
    preds = model.predict(X)
    fullmodel_encoded=fullmodel_encoded.iloc[1:]
    # Add predictions and residuals to the dataframe
    fullmodel_encoded['Preds'] = preds
    fullmodel_encoded['resids']=fullmodel_encoded['ETH_price']-fullmodel_encoded['Preds']
    resids = fullmodel_encoded['ETH_price']-fullmodel_encoded['Preds']

    return model, preds, resids,fullmodel_encoded,X

# %%
full_model, preds, resids,real,X = model_trend_seasonality(train_df.copy())

# Calculate the model performance statistics
# mse = np.sum(resids**2,axis=0)/flights_per_day.shape[0]
# r2 = 1 - np.sum((resids)**2)/np.sum((flights_per_day-np.mean(flights_per_day))**2)

# Display the model and performance metrics
print('The fitted model is:')
# Get the equation for the model
coef = full_model.coef_
intercept = full_model.intercept_

# Print out the equation
equation = 'y = {:.2f} + '.format(intercept) + ' + '.join(['{:.2f}*{}'.format(coef,var) for coef,var in zip(coef,X.columns)])
print(equation)

r2_autocorr = r2_score(real['ETH_price'], preds)
mae_autocorr = mean_absolute_error(real['ETH_price'], preds)
print('The simple linear model has R^2={:.3f},MAE={:.2f}'.format(r2_autocorr, mae_autocorr))

overall['linear_regression_seasonality']={'train': {'mae':mae_autocorr,"r2":r2_autocorr}}

# Plot the data and the predictions
plt.figure(figsize=(15,10))
plt.scatter(x=real.index, y=real['ETH_price'])
plt.plot(real.index, preds,color='red')
plt.xlim((real.index.min(),real.index.max()))
plt.ylabel('Training Price of ETH')
plt.show()
# Out:
#                                   ETH_marketcap  Day_of_hour_0  Day_of_hour_1  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00   1.457664e+10              0              0
# 2019-01-02 00:59:59.999000+00:00   1.466532e+10              1              0
# 2019-01-02 01:59:59.999000+00:00   1.478792e+10              0              1
# 2019-01-02 02:59:59.999000+00:00   1.469747e+10              0              0
# 2019-01-02 03:59:59.999000+00:00   1.469218e+10              0              0
#
#                                   Day_of_hour_2  Day_of_hour_3  Day_of_hour_4  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00              0              0              0
# 2019-01-02 00:59:59.999000+00:00              0              0              0
# 2019-01-02 01:59:59.999000+00:00              0              0              0
# 2019-01-02 02:59:59.999000+00:00              1              0              0
# 2019-01-02 03:59:59.999000+00:00              0              1              0
#
#                                   Day_of_hour_5  Day_of_hour_6  Day_of_hour_7  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00              0              0              0
# 2019-01-02 00:59:59.999000+00:00              0              0              0
# 2019-01-02 01:59:59.999000+00:00              0              0              0
# 2019-01-02 02:59:59.999000+00:00              0              0              0
# 2019-01-02 03:59:59.999000+00:00              0              0              0
#
#                                   Day_of_hour_8  ...  Day_of_hour_15  \
# timeclose                                        ...
# 2019-01-01 23:59:59.999000+00:00              0  ...               0
# 2019-01-02 00:59:59.999000+00:00              0  ...               0
# 2019-01-02 01:59:59.999000+00:00              0  ...               0
# 2019-01-02 02:59:59.999000+00:00              0  ...               0
# 2019-01-02 03:59:59.999000+00:00              0  ...               0
#
#                                   Day_of_hour_16  Day_of_hour_17  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00               0               0
# 2019-01-02 00:59:59.999000+00:00               0               0
# 2019-01-02 01:59:59.999000+00:00               0               0
# 2019-01-02 02:59:59.999000+00:00               0               0
# 2019-01-02 03:59:59.999000+00:00               0               0
#
#                                   Day_of_hour_18  Day_of_hour_19  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00               0               0
# 2019-01-02 00:59:59.999000+00:00               0               0
# 2019-01-02 01:59:59.999000+00:00               0               0
# 2019-01-02 02:59:59.999000+00:00               0               0
# 2019-01-02 03:59:59.999000+00:00               0               0
#
#                                   Day_of_hour_20  Day_of_hour_21  \
# timeclose
# 2019-01-01 23:59:59.999000+00:00               0               0
# 2019-01-02 00:59:59.999000+00:00               0               0
# 2019-01-02 01:59:59.999000+00:00               0               0
# 2019-01-02 02:59:59.999000+00:00               0               0
# 2019-01-02 03:59:59.999000+00:00               0               0
#
#                                   Day_of_hour_22  Day_of_hour_23  Days
# timeclose
# 2019-01-01 23:59:59.999000+00:00               0               1     0
# 2019-01-02 00:59:59.999000+00:00               0               0     0
# 2019-01-02 01:59:59.999000+00:00               0               0     0
# 2019-01-02 02:59:59.999000+00:00               0               0     0
# 2019-01-02 03:59:59.999000+00:00               0               0     0
#
# [5 rows x 26 columns]
# The fitted model is:
# y = 30.53 + 0.00*ETH_marketcap + -0.73*Day_of_hour_0 + 0.40*Day_of_hour_1 + -1.16*Day_of_hour_2 + -0.76*Day_of_hour_3 + 0.17*Day_of_hour_4 + 0.60*Day_of_hour_5 + 0.15*Day_of_hour_6 + 0.33*Day_of_hour_7 + -0.13*Day_of_hour_8 + -0.50*Day_of_hour_9 + 0.15*Day_of_hour_10 + -0.19*Day_of_hour_11 + 0.04*Day_of_hour_12 + 1.23*Day_of_hour_13 + -1.21*Day_of_hour_14 + 0.06*Day_of_hour_15 + 0.37*Day_of_hour_16 + -0.54*Day_of_hour_17 + 0.13*Day_of_hour_18 + 0.36*Day_of_hour_19 + -0.26*Day_of_hour_20 + 1.35*Day_of_hour_21 + 0.12*Day_of_hour_22 + 0.04*Day_of_hour_23 + -0.03*Days
# The simple linear model has R^2=1.000,MAE=18.79

# %%
from sklearn.metrics import r2_score,mean_absolute_error
regressionData = test_df.copy()
regressionData['Days'] = (regressionData.index-regressionData.index.min()).days
regressionData['Day_of_hour'] = regressionData.index.hour
regressionData = pd.get_dummies(data = regressionData, columns=['Day_of_hour'])
regressionData['ETH_marketcap'] = regressionData['ETH_marketcap'].shift()
regressionData = regressionData.iloc[1:]
X = regressionData.drop(['ETH_price', 'ETH_volume','ds','y','add1','ETH_returns'],axis=1)
preds = full_model.predict(X)
r2_test_season = r2_score(regressionData['ETH_price'], preds)
mae_test_season = mean_absolute_error(regressionData['ETH_price'], preds)
print('The simple linear model has R^2={:.3f},MAE={:.2f}'.format(r2_test_season, mae_test_season))
overall['linear_regression_seasonality']['test']={'mae':mae_test_season,"r2":r2_test_season}

# Plot the data and the predictions
plt.figure(figsize=(15,10))
plt.scatter(x=regressionData.index, y=regressionData['ETH_price'])
plt.plot(regressionData.index, preds,color='red')
plt.xlim((regressionData.index[days_lag:].min(),regressionData.index[days_lag:].max()))
plt.ylabel('Test dateset for ETH Price')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# The simple linear model has R^2=0.976,MAE=33.46

# %%
#LSTM model

BATCH_SIZE=60
N_EPOCHS = 60

def create_input_data(series, n_lags=1, n_leads=1):
    '''
    Function for transforming time series into input acceptable by a multilayer perceptron.

    Parameters
    ----------
    series : np.array
        The time series to be transformed
    n_lags : int
        The number of lagged observations to consider as features
    n_leads : int
        The number of future periods we want to forecast for

    Returns
    -------
    X : np.array
        Array of features
    y : np.array
        Array of target
    '''
    X = []
    y = []
    for step in range(len(series) - n_lags - n_leads + 1):
        end_step = step + n_lags
        forward_end = end_step + n_leads
        X.append(series[step:end_step])
        y.append(series[end_step:forward_end][0][0])
    return np.array(X), np.array(y)

# custom function for reproducibility


def custom_set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
prices = df[['ETH_price','ETH_marketcap']].values

# %%
valid_size = test_df.shape[0]
valid_ind = len(prices) - valid_size


minmax = MinMaxScaler(feature_range=(0, 1))

prices_train = prices[:valid_ind]
prices_valid = prices[valid_ind:]

minmax.fit(prices_train)

prices_train = minmax.transform(prices_train)
prices_valid = minmax.transform(prices_valid)

# prices_scaled = np.concatenate((prices_train,
#                                 prices_valid)).flatten()
prices_scaled = np.concatenate((prices_train,
                                prices_valid))

prices_scaled.shape
# Out:
# (31674, 2)

# %%
X, y = create_input_data(prices_scaled, 12)
y=y.reshape(-1,1)

print(X.shape,y.shape)
# Out:
# (31662, 12, 2) (31662, 1)

# %%
# set seed for reproducibility
custom_set_seed(42)

valid_ind = len(X) - valid_size
print(X.shape[0],X.shape[1],1)
# X_tensor = torch.from_numpy(X).float().reshape(X.shape[0],
#                                                X.shape[1],
#                                                2)
X_tensor = torch.from_numpy(X).float().reshape(X.shape[0],
                                               X.shape[1],
                                               2)
y_tensor = torch.from_numpy(y).float().reshape(X.shape[0], 1)

dataset = TensorDataset(X_tensor, y_tensor)

train_dataset = Subset(dataset, list(range(valid_ind)))
valid_dataset = Subset(dataset, list(range(valid_ind, len(X))))

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset,
                          batch_size=BATCH_SIZE)
# Out:
# 31662 12 1

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, n_layers, output_size):
        super(RNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size,
                          n_layers, batch_first=True,
                          nonlinearity='relu')
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        output, _ = self.rnn(x)
        output = self.fc(output[:,-1,:])
        return output

# %%
model = RNN(input_size=2, hidden_size=6,
            n_layers=1, output_size=1).to(device)
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
PRINT_EVERY = 10
train_losses, valid_losses = [], []

for epoch in range(N_EPOCHS):
    running_loss_train = 0
    running_loss_valid = 0

    model.train()

    for x_batch, y_batch in train_loader:

        optimizer.zero_grad()

        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        y_hat = model(x_batch)
        loss = torch.sqrt(loss_fn(y_batch, y_hat))
        loss.backward()
        optimizer.step()
        running_loss_train += loss.item() * x_batch.size(0)

    epoch_loss_train = running_loss_train / len(train_loader.dataset)
    train_losses.append(epoch_loss_train)

    with torch.no_grad():
        model.eval()
        for x_val, y_val in valid_loader:
            x_val = x_val.to(device)
            y_val = y_val.to(device)
            y_hat = model(x_val)
            loss = torch.sqrt(loss_fn(y_val, y_hat))
            running_loss_valid += loss.item() * x_val.size(0)

        epoch_loss_valid = running_loss_valid / len(valid_loader.dataset)

        if epoch > 0 and epoch_loss_valid < min(valid_losses):
            best_epoch = epoch
            torch.save(model.state_dict(), 'eth_rnn_checkpoint.pth')

        valid_losses.append(epoch_loss_valid)

    if epoch % PRINT_EVERY == 0:
        print(f"<{epoch}> - Train. loss: {epoch_loss_train:.4f} \t Valid. loss: {epoch_loss_valid:.4f}")

print(f'Lowest loss recorded in epoch: {best_epoch}')
# Out:
# <0> - Train. loss: 0.0860 	 Valid. loss: 0.0054
# <10> - Train. loss: 0.0050 	 Valid. loss: 0.0037
# <20> - Train. loss: 0.0045 	 Valid. loss: 0.0034
# <30> - Train. loss: 0.0042 	 Valid. loss: 0.0038
# <40> - Train. loss: 0.0040 	 Valid. loss: 0.0031
# <50> - Train. loss: 0.0039 	 Valid. loss: 0.0028
# Lowest loss recorded in epoch: 54

# %%
train_losses = np.array(train_losses)
valid_losses = np.array(valid_losses)

fig, ax = plt.subplots()

ax.plot(train_losses, color='blue', label='Training loss')
ax.plot(valid_losses, color='red', label='Validation loss')

ax.set(title="Loss over epochs",
       xlabel='Epoch',
       ylabel='Loss')
ax.legend()

# plt.tight_layout()
# plt.savefig('images/ch10_im14.png')
plt.show()

# %%
state_dict = torch.load('eth_rnn_checkpoint.pth')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
y_pred = []

with torch.no_grad():

    model.eval()

    for x_val, y_val in train_loader:
        x_val = x_val.to(device)
        y_hat = model(x_val)
        y_pred.append(y_hat)
scaler = MinMaxScaler(feature_range=(0, 1))

scaler.min_,scaler.scale_=minmax.min_[0],minmax.scale_[0]
y_pred = torch.cat(y_pred).numpy()

y_pred = scaler.inverse_transform(y_pred).flatten()
y_valid = prices[0:len(prices)-valid_size-12]

rnn_mse = mean_absolute_error(y_valid[:,0], y_pred)
rnn_R2=r2_score(y_valid[:,0], y_pred)
overall['rnn']={'train': {'mae':rnn_mse,"r2":rnn_R2}}
print(f"Training RNN's forecast - MAE: {rnn_mse:.4f},R2: {rnn_R2:.4f}")
# Out:
# Training RNN's forecast - MAE: 1433.6175,R2: -1.0073

# %%
y_pred = []

with torch.no_grad():

    model.eval()

    for x_val, y_val in valid_loader:
        x_val = x_val.to(device)
        y_hat = model(x_val)
        y_pred.append(y_hat)


y_pred = torch.cat(y_pred).numpy()

y_pred = scaler.inverse_transform(y_pred).flatten()

# %%
y_valid = prices[len(prices)-valid_size:]

rnn_mse = mean_absolute_error(y_valid[:,0], y_pred)
rnn_R2=r2_score(y_valid[:,0], y_pred)
overall['rnn']['test']={'mae':rnn_mse,"r2":rnn_R2}

print(f"RNN's forecast - MAE: {rnn_mse:.4f},R2: {rnn_R2:.4f}")

fig, ax = plt.subplots(figsize=(12,9))

ax.scatter(test_df.index,y_valid[:,0], color='blue', label='Actual')
ax.plot(test_df.index,y_pred, color='red', label='RNN')

ax.set(title="RNN's Forecasts",
       xlabel='Time',
       ylabel='Price ($)')
ax.legend()

# plt.tight_layout()
plt.show()
# Out:
# RNN's forecast - MAE: 9.0144,R2: 0.9972

# %%
# facebook model
display(train_df.head())
model = Prophet(seasonality_mode='multiplicative')
model.add_regressor('add1')
model.fit(train_df)
# Out:
#                                    ETH_price  ETH_returns  ETH_marketcap  \
# timeclose
# 2019-01-01 22:59:59.999000+00:00  139.968871     0.001954   1.457664e+10
# 2019-01-01 23:59:59.999000+00:00  140.819413     0.006077   1.466532e+10
# 2019-01-02 00:59:59.999000+00:00  141.995471     0.008352   1.478792e+10
# 2019-01-02 01:59:59.999000+00:00  141.125948    -0.006124   1.469747e+10
# 2019-01-02 02:59:59.999000+00:00  141.074109    -0.000367   1.469218e+10
#
#                                   ETH_volume                      ds  \
# timeclose
# 2019-01-01 22:59:59.999000+00:00         NaN 2019-01-01 22:59:59.999
# 2019-01-01 23:59:59.999000+00:00         NaN 2019-01-01 23:59:59.999
# 2019-01-02 00:59:59.999000+00:00         NaN 2019-01-02 00:59:59.999
# 2019-01-02 01:59:59.999000+00:00         NaN 2019-01-02 01:59:59.999
# 2019-01-02 02:59:59.999000+00:00         NaN 2019-01-02 02:59:59.999
#
#                                            y          add1
# timeclose
# 2019-01-01 22:59:59.999000+00:00  139.968871  1.454810e+10
# 2019-01-01 23:59:59.999000+00:00  140.819413  1.457664e+10
# 2019-01-02 00:59:59.999000+00:00  141.995471  1.466532e+10
# 2019-01-02 01:59:59.999000+00:00  141.125948  1.478792e+10
# 2019-01-02 02:59:59.999000+00:00  141.074109  1.469747e+10
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqt17s1_9/cp3t815r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqt17s1_9/ie45wqkn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30094', 'data', 'file=/tmp/tmpqt17s1_9/cp3t815r.json', 'init=/tmp/tmpqt17s1_9/ie45wqkn.json', 'output', 'file=/tmp/tmpqt17s1_9/prophet_modelgjcnxlbe/prophet_model-20221102040205.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:02:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:02:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = train_df[['ds','add1']] # Put in format needed
forecast_insample = model.predict(future) # Get the predictions for the week
forecast_insample.T # Display
# Out:
#                                                             0      \
# ds                                     2019-01-01 22:59:59.999000
# trend                                                 1267.216152
# yhat_lower                                             109.095556
# yhat_upper                                              159.30139
# trend_lower                                           1267.216152
# trend_upper                                           1267.216152
# add1                                                    -0.896396
# add1_lower                                              -0.896396
# add1_upper                                              -0.896396
# daily                                                    0.000323
# daily_lower                                              0.000323
# daily_upper                                              0.000323
# extra_regressors_multiplicative                         -0.896396
# extra_regressors_multiplicative_lower                   -0.896396
# extra_regressors_multiplicative_upper                   -0.896396
# multiplicative_terms                                    -0.894387
# multiplicative_terms_lower                              -0.894387
# multiplicative_terms_upper                              -0.894387
# weekly                                                     0.0001
# weekly_lower                                               0.0001
# weekly_upper                                               0.0001
# yearly                                                   0.001585
# yearly_lower                                             0.001585
# yearly_upper                                             0.001585
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   133.833884
#
#                                                             1      \
# ds                                     2019-01-01 23:59:59.999000
# trend                                                 1267.261458
# yhat_lower                                              109.95126
# yhat_upper                                             160.794011
# trend_lower                                           1267.261458
# trend_upper                                           1267.261458
# add1                                                    -0.896202
# add1_lower                                              -0.896202
# add1_upper                                              -0.896202
# daily                                                     0.00013
# daily_lower                                               0.00013
# daily_upper                                               0.00013
# extra_regressors_multiplicative                         -0.896202
# extra_regressors_multiplicative_lower                   -0.896202
# extra_regressors_multiplicative_upper                   -0.896202
# multiplicative_terms                                    -0.894354
# multiplicative_terms_lower                              -0.894354
# multiplicative_terms_upper                              -0.894354
# weekly                                                   0.000126
# weekly_lower                                             0.000126
# weekly_upper                                             0.000126
# yearly                                                   0.001592
# yearly_lower                                             0.001592
# yearly_upper                                             0.001592
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   133.880596
#
#                                                             2      \
# ds                                     2019-01-02 00:59:59.999000
# trend                                                 1267.306765
# yhat_lower                                             108.421409
# yhat_upper                                              159.45733
# trend_lower                                           1267.306765
# trend_upper                                           1267.306765
# add1                                                    -0.895599
# add1_lower                                              -0.895599
# add1_upper                                              -0.895599
# daily                                                   -0.000195
# daily_lower                                             -0.000195
# daily_upper                                             -0.000195
# extra_regressors_multiplicative                         -0.895599
# extra_regressors_multiplicative_lower                   -0.895599
# extra_regressors_multiplicative_upper                   -0.895599
# multiplicative_terms                                    -0.894044
# multiplicative_terms_lower                              -0.894044
# multiplicative_terms_upper                              -0.894044
# weekly                                                   0.000151
# weekly_lower                                             0.000151
# weekly_upper                                             0.000151
# yearly                                                   0.001599
# yearly_lower                                             0.001599
# yearly_upper                                             0.001599
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                     134.2792
#
#                                                             3      \
# ds                                     2019-01-02 01:59:59.999000
# trend                                                 1267.352072
# yhat_lower                                             111.051976
# yhat_upper                                             160.152079
# trend_lower                                           1267.352072
# trend_upper                                           1267.352072
# add1                                                    -0.894765
# add1_lower                                              -0.894765
# add1_upper                                              -0.894765
# daily                                                   -0.000499
# daily_lower                                             -0.000499
# daily_upper                                             -0.000499
# extra_regressors_multiplicative                         -0.894765
# extra_regressors_multiplicative_lower                   -0.894765
# extra_regressors_multiplicative_upper                   -0.894765
# multiplicative_terms                                    -0.893482
# multiplicative_terms_lower                              -0.893482
# multiplicative_terms_upper                              -0.893482
# weekly                                                   0.000176
# weekly_lower                                             0.000176
# weekly_upper                                             0.000176
# yearly                                                   0.001606
# yearly_lower                                             0.001606
# yearly_upper                                             0.001606
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   134.995984
#
#                                                             4      \
# ds                                     2019-01-02 02:59:59.999000
# trend                                                 1267.397379
# yhat_lower                                             109.741275
# yhat_upper                                             158.224219
# trend_lower                                           1267.397379
# trend_upper                                           1267.397379
# add1                                                     -0.89538
# add1_lower                                               -0.89538
# add1_upper                                               -0.89538
# daily                                                   -0.000592
# daily_lower                                             -0.000592
# daily_upper                                             -0.000592
# extra_regressors_multiplicative                          -0.89538
# extra_regressors_multiplicative_lower                    -0.89538
# extra_regressors_multiplicative_upper                    -0.89538
# multiplicative_terms                                     -0.89416
# multiplicative_terms_lower                               -0.89416
# multiplicative_terms_upper                               -0.89416
# weekly                                                   0.000199
# weekly_lower                                             0.000199
# weekly_upper                                             0.000199
# yearly                                                   0.001613
# yearly_lower                                             0.001613
# yearly_upper                                             0.001613
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   134.141108
#
#                                                             5      \
# ds                                     2019-01-02 03:59:59.999000
# trend                                                 1267.442685
# yhat_lower                                             110.635736
# yhat_upper                                             159.149513
# trend_lower                                           1267.442685
# trend_upper                                           1267.442685
# add1                                                    -0.895416
# add1_lower                                              -0.895416
# add1_upper                                              -0.895416
# daily                                                   -0.000398
# daily_lower                                             -0.000398
# daily_upper                                             -0.000398
# extra_regressors_multiplicative                         -0.895416
# extra_regressors_multiplicative_lower                   -0.895416
# extra_regressors_multiplicative_upper                   -0.895416
# multiplicative_terms                                    -0.893972
# multiplicative_terms_lower                              -0.893972
# multiplicative_terms_upper                              -0.893972
# weekly                                                   0.000222
# weekly_lower                                             0.000222
# weekly_upper                                             0.000222
# yearly                                                    0.00162
# yearly_lower                                              0.00162
# yearly_upper                                              0.00162
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   134.383949
#
#                                                             6      \
# ds                                     2019-01-02 04:59:59.999000
# trend                                                 1267.487992
# yhat_lower                                             110.794905
# yhat_upper                                             158.818572
# trend_lower                                           1267.487992
# trend_upper                                           1267.487992
# add1                                                    -0.895247
# add1_lower                                              -0.895247
# add1_upper                                              -0.895247
# daily                                                    -0.00003
# daily_lower                                              -0.00003
# daily_upper                                              -0.00003
# extra_regressors_multiplicative                         -0.895247
# extra_regressors_multiplicative_lower                   -0.895247
# extra_regressors_multiplicative_upper                   -0.895247
# multiplicative_terms                                    -0.893408
# multiplicative_terms_lower                              -0.893408
# multiplicative_terms_upper                              -0.893408
# weekly                                                   0.000243
# weekly_lower                                             0.000243
# weekly_upper                                             0.000243
# yearly                                                   0.001626
# yearly_lower                                             0.001626
# yearly_upper                                             0.001626
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   135.103761
#
#                                                             7      \
# ds                                     2019-01-02 05:59:59.999000
# trend                                                 1267.533299
# yhat_lower                                             109.177732
# yhat_upper                                             159.683305
# trend_lower                                           1267.533299
# trend_upper                                           1267.533299
# add1                                                    -0.895171
# add1_lower                                              -0.895171
# add1_upper                                              -0.895171
# daily                                                    0.000271
# daily_lower                                              0.000271
# daily_upper                                              0.000271
# extra_regressors_multiplicative                         -0.895171
# extra_regressors_multiplicative_lower                   -0.895171
# extra_regressors_multiplicative_upper                   -0.895171
# multiplicative_terms                                    -0.893005
# multiplicative_terms_lower                              -0.893005
# multiplicative_terms_upper                              -0.893005
# weekly                                                   0.000262
# weekly_lower                                             0.000262
# weekly_upper                                             0.000262
# yearly                                                   0.001633
# yearly_lower                                             0.001633
# yearly_upper                                             0.001633
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   135.619295
#
#                                                             8      \
# ds                                     2019-01-02 06:59:59.999000
# trend                                                 1267.578605
# yhat_lower                                             109.754267
# yhat_upper                                             161.248768
# trend_lower                                           1267.578605
# trend_upper                                           1267.578605
# add1                                                    -0.895228
# add1_lower                                              -0.895228
# add1_upper                                              -0.895228
# daily                                                    0.000321
# daily_lower                                              0.000321
# daily_upper                                              0.000321
# extra_regressors_multiplicative                         -0.895228
# extra_regressors_multiplicative_lower                   -0.895228
# extra_regressors_multiplicative_upper                   -0.895228
# multiplicative_terms                                    -0.892988
# multiplicative_terms_lower                              -0.892988
# multiplicative_terms_upper                              -0.892988
# weekly                                                   0.000279
# weekly_lower                                             0.000279
# weekly_upper                                             0.000279
# yearly                                                    0.00164
# yearly_lower                                              0.00164
# yearly_upper                                              0.00164
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   135.646451
#
#                                                             9      ...  \
# ds                                     2019-01-02 07:59:59.999000  ...
# trend                                                 1267.623912  ...
# yhat_lower                                             111.486681  ...
# yhat_upper                                              159.64483  ...
# trend_lower                                           1267.623912  ...
# trend_upper                                           1267.623912  ...
# add1                                                    -0.895389  ...
# add1_lower                                              -0.895389  ...
# add1_upper                                              -0.895389  ...
# daily                                                     0.00013  ...
# daily_lower                                               0.00013  ...
# daily_upper                                               0.00013  ...
# extra_regressors_multiplicative                         -0.895389  ...
# extra_regressors_multiplicative_lower                   -0.895389  ...
# extra_regressors_multiplicative_upper                   -0.895389  ...
# multiplicative_terms                                    -0.893319  ...
# multiplicative_terms_lower                              -0.893319  ...
# multiplicative_terms_upper                              -0.893319  ...
# weekly                                                   0.000294  ...
# weekly_lower                                             0.000294  ...
# weekly_upper                                             0.000294  ...
# yearly                                                   0.001647  ...
# yearly_lower                                             0.001647  ...
# yearly_upper                                             0.001647  ...
# additive_terms                                                0.0  ...
# additive_terms_lower                                          0.0  ...
# additive_terms_upper                                          0.0  ...
# yhat                                                   135.231901  ...
#
#                                                             28344  \
# ds                                     2022-05-25 15:59:59.999000
# trend                                                 1212.427903
# yhat_lower                                            1943.221723
# yhat_upper                                            1990.284646
# trend_lower                                           1212.427903
# trend_upper                                           1212.427903
# add1                                                     0.623346
# add1_lower                                               0.623346
# add1_upper                                               0.623346
# daily                                                   -0.000123
# daily_lower                                             -0.000123
# daily_upper                                             -0.000123
# extra_regressors_multiplicative                          0.623346
# extra_regressors_multiplicative_lower                    0.623346
# extra_regressors_multiplicative_upper                    0.623346
# multiplicative_terms                                     0.622443
# multiplicative_terms_lower                               0.622443
# multiplicative_terms_upper                               0.622443
# weekly                                                   0.000312
# weekly_lower                                             0.000312
# weekly_upper                                             0.000312
# yearly                                                  -0.001092
# yearly_lower                                            -0.001092
# yearly_upper                                            -0.001092
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                   1967.09489
#
#                                                             28345  \
# ds                                     2022-05-25 16:59:59.999000
# trend                                                 1212.421821
# yhat_lower                                            1937.244487
# yhat_upper                                            1986.697022
# trend_lower                                           1212.421821
# trend_upper                                           1212.421821
# add1                                                     0.619115
# add1_lower                                               0.619115
# add1_upper                                               0.619115
# daily                                                   -0.000144
# daily_lower                                             -0.000144
# daily_upper                                             -0.000144
# extra_regressors_multiplicative                          0.619115
# extra_regressors_multiplicative_lower                    0.619115
# extra_regressors_multiplicative_upper                    0.619115
# multiplicative_terms                                     0.618182
# multiplicative_terms_lower                               0.618182
# multiplicative_terms_upper                               0.618182
# weekly                                                   0.000301
# weekly_lower                                             0.000301
# weekly_upper                                             0.000301
# yearly                                                   -0.00109
# yearly_lower                                             -0.00109
# yearly_upper                                             -0.00109
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1961.919033
#
#                                                             28346  \
# ds                                     2022-05-25 17:59:59.999000
# trend                                                  1212.41574
# yhat_lower                                             1923.79056
# yhat_upper                                            1975.655947
# trend_lower                                            1212.41574
# trend_upper                                            1212.41574
# add1                                                     0.609767
# add1_lower                                               0.609767
# add1_upper                                               0.609767
# daily                                                   -0.000066
# daily_lower                                             -0.000066
# daily_upper                                             -0.000066
# extra_regressors_multiplicative                          0.609767
# extra_regressors_multiplicative_lower                    0.609767
# extra_regressors_multiplicative_upper                    0.609767
# multiplicative_terms                                       0.6089
# multiplicative_terms_lower                                 0.6089
# multiplicative_terms_upper                                 0.6089
# weekly                                                   0.000287
# weekly_lower                                             0.000287
# weekly_upper                                             0.000287
# yearly                                                  -0.001088
# yearly_lower                                            -0.001088
# yearly_upper                                            -0.001088
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1950.655179
#
#                                                             28347  \
# ds                                     2022-05-25 18:59:59.999000
# trend                                                 1212.409658
# yhat_lower                                            1932.418014
# yhat_upper                                            1984.815668
# trend_lower                                           1212.409658
# trend_upper                                           1212.409658
# add1                                                     0.616814
# add1_lower                                               0.616814
# add1_upper                                               0.616814
# daily                                                    0.000054
# daily_lower                                              0.000054
# daily_upper                                              0.000054
# extra_regressors_multiplicative                          0.616814
# extra_regressors_multiplicative_lower                    0.616814
# extra_regressors_multiplicative_upper                    0.616814
# multiplicative_terms                                     0.616051
# multiplicative_terms_lower                               0.616051
# multiplicative_terms_upper                               0.616051
# weekly                                                    0.00027
# weekly_lower                                              0.00027
# weekly_upper                                              0.00027
# yearly                                                  -0.001086
# yearly_lower                                            -0.001086
# yearly_upper                                            -0.001086
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1959.316174
#
#                                                             28348  \
# ds                                     2022-05-25 19:59:59.999000
# trend                                                 1212.403576
# yhat_lower                                            1948.936773
# yhat_upper                                            1996.034302
# trend_lower                                           1212.403576
# trend_upper                                           1212.403576
# add1                                                     0.627012
# add1_lower                                               0.627012
# add1_upper                                               0.627012
# daily                                                    0.000175
# daily_lower                                              0.000175
# daily_upper                                              0.000175
# extra_regressors_multiplicative                          0.627012
# extra_regressors_multiplicative_lower                    0.627012
# extra_regressors_multiplicative_upper                    0.627012
# multiplicative_terms                                     0.626352
# multiplicative_terms_lower                               0.626352
# multiplicative_terms_upper                               0.626352
# weekly                                                    0.00025
# weekly_lower                                              0.00025
# weekly_upper                                              0.00025
# yearly                                                  -0.001084
# yearly_lower                                            -0.001084
# yearly_upper                                            -0.001084
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1971.795508
#
#                                                             28349  \
# ds                                     2022-05-25 20:59:59.999000
# trend                                                 1212.397495
# yhat_lower                                            1929.222907
# yhat_upper                                            1979.998728
# trend_lower                                           1212.397495
# trend_upper                                           1212.397495
# add1                                                     0.613746
# add1_lower                                               0.613746
# add1_upper                                               0.613746
# daily                                                    0.000283
# daily_lower                                              0.000283
# daily_upper                                              0.000283
# extra_regressors_multiplicative                          0.613746
# extra_regressors_multiplicative_lower                    0.613746
# extra_regressors_multiplicative_upper                    0.613746
# multiplicative_terms                                     0.613175
# multiplicative_terms_lower                               0.613175
# multiplicative_terms_upper                               0.613175
# weekly                                                   0.000228
# weekly_lower                                             0.000228
# weekly_upper                                             0.000228
# yearly                                                  -0.001082
# yearly_lower                                            -0.001082
# yearly_upper                                            -0.001082
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1955.808729
#
#                                                             28350  \
# ds                                     2022-05-25 21:59:59.999000
# trend                                                 1212.391413
# yhat_lower                                            1934.733291
# yhat_upper                                            1984.060206
# trend_lower                                           1212.391413
# trend_upper                                           1212.391413
# add1                                                     0.617433
# add1_lower                                               0.617433
# add1_upper                                               0.617433
# daily                                                    0.000355
# daily_lower                                              0.000355
# daily_upper                                              0.000355
# extra_regressors_multiplicative                          0.617433
# extra_regressors_multiplicative_lower                    0.617433
# extra_regressors_multiplicative_upper                    0.617433
# multiplicative_terms                                     0.616911
# multiplicative_terms_lower                               0.616911
# multiplicative_terms_upper                               0.616911
# weekly                                                   0.000203
# weekly_lower                                             0.000203
# weekly_upper                                             0.000203
# yearly                                                  -0.001081
# yearly_lower                                            -0.001081
# yearly_upper                                            -0.001081
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1960.328809
#
#                                                             28351  \
# ds                                     2022-05-25 22:59:59.999000
# trend                                                 1212.385332
# yhat_lower                                            1941.211998
# yhat_upper                                            1991.015886
# trend_lower                                           1212.385332
# trend_upper                                           1212.385332
# add1                                                     0.621374
# add1_lower                                               0.621374
# add1_upper                                               0.621374
# daily                                                    0.000323
# daily_lower                                              0.000323
# daily_upper                                              0.000323
# extra_regressors_multiplicative                          0.621374
# extra_regressors_multiplicative_lower                    0.621374
# extra_regressors_multiplicative_upper                    0.621374
# multiplicative_terms                                     0.620795
# multiplicative_terms_lower                               0.620795
# multiplicative_terms_upper                               0.620795
# weekly                                                   0.000177
# weekly_lower                                             0.000177
# weekly_upper                                             0.000177
# yearly                                                  -0.001079
# yearly_lower                                            -0.001079
# yearly_upper                                            -0.001079
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1965.027884
#
#                                                             28352  \
# ds                                     2022-05-25 23:59:59.999000
# trend                                                  1212.37925
# yhat_lower                                            1938.810222
# yhat_upper                                            1988.949606
# trend_lower                                            1212.37925
# trend_upper                                            1212.37925
# add1                                                     0.619037
# add1_lower                                               0.619037
# add1_upper                                               0.619037
# daily                                                     0.00013
# daily_lower                                               0.00013
# daily_upper                                               0.00013
# extra_regressors_multiplicative                          0.619037
# extra_regressors_multiplicative_lower                    0.619037
# extra_regressors_multiplicative_upper                    0.619037
# multiplicative_terms                                     0.618239
# multiplicative_terms_lower                               0.618239
# multiplicative_terms_upper                               0.618239
# weekly                                                   0.000148
# weekly_lower                                             0.000148
# weekly_upper                                             0.000148
# yearly                                                  -0.001077
# yearly_lower                                            -0.001077
# yearly_upper                                            -0.001077
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1961.918799
#
#                                                             28353
# ds                                     2022-05-26 00:59:59.999000
# trend                                                 1212.373168
# yhat_lower                                            1918.620688
# yhat_upper                                            1967.016218
# trend_lower                                           1212.373168
# trend_upper                                           1212.373168
# add1                                                     0.604323
# add1_lower                                               0.604323
# add1_upper                                               0.604323
# daily                                                   -0.000195
# daily_lower                                             -0.000195
# daily_upper                                             -0.000195
# extra_regressors_multiplicative                          0.604323
# extra_regressors_multiplicative_lower                    0.604323
# extra_regressors_multiplicative_upper                    0.604323
# multiplicative_terms                                     0.603171
# multiplicative_terms_lower                               0.603171
# multiplicative_terms_upper                               0.603171
# weekly                                                   0.000118
# weekly_lower                                             0.000118
# weekly_upper                                             0.000118
# yearly                                                  -0.001075
# yearly_lower                                            -0.001075
# yearly_upper                                            -0.001075
# additive_terms                                                0.0
# additive_terms_lower                                          0.0
# additive_terms_upper                                          0.0
# yhat                                                  1943.641652
#
# [28 rows x 28354 columns]

# %%
model.plot_components(forecast_insample)
plt.show()

# %%
model.plot(forecast_insample);

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error

metric_df = forecast_insample.set_index('ds')[['yhat']].join(train_df.set_index('ds').y).reset_index()
metric_df.dropna(inplace=True)
mae_fb = mean_absolute_error(metric_df.y, metric_df.yhat)
r2_fb = r2_score(metric_df.y, metric_df.yhat)
print(f'Training MAE scores: {mae_fb}')
overall['fb_model']={'train': {'mae':mae_fb,"r2":r2_fb}}
# Out:
# Training MAE scores: 8.26601141933685

# %%
future = test_df[['ds','add1']]  # Put in format needed
forecast_insample = model.predict(future)  # Get the predictions for the week
metric_df = forecast_insample.set_index('ds')[['yhat']].join(test_df.set_index('ds').y).reset_index()
metric_df.dropna(inplace=True)
r2_fb_test = r2_score(metric_df.y, metric_df.yhat)
print(f'Testing R2 scores: {r2_fb_test}')
mae_fb_test = mean_absolute_error(metric_df.y, metric_df.yhat)
print(f'Testing MAE scores: {mae_fb_test}')
print(f'Testing Accuracy: {1-mean_absolute_percentage_error(metric_df.y, metric_df.yhat)}')
overall['fb_model']['test']={'mae':mae_fb_test,"r2":r2_fb_test}
# Out:
# Testing R2 scores: 0.9973133935190343
# Testing MAE scores: 9.011381043136094
# Testing Accuracy: 0.99377915694514

# %%
forecast_insample.head()
# Out:
#                        ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0 2022-05-26 01:59:59.999  1212.367087  1932.123979  1979.785420  1212.367087
# 1 2022-05-26 02:59:59.999  1212.361005  1920.172597  1970.394128  1212.361005
# 2 2022-05-26 03:59:59.999  1212.354924  1928.742709  1976.461375  1212.354924
# 3 2022-05-26 04:59:59.999  1212.348842  1921.197951  1970.387426  1212.348842
# 4 2022-05-26 05:59:59.999  1212.342760  1913.817442  1963.803024  1212.342760
#
#    trend_upper      add1  add1_lower  add1_upper     daily  ...    weekly  \
# 0  1212.367087  0.614988    0.614988    0.614988 -0.000499  ...  0.000087
# 1  1212.361005  0.605749    0.605749    0.605749 -0.000592  ...  0.000055
# 2  1212.354924  0.612253    0.612253    0.612253 -0.000398  ...  0.000022
# 3  1212.348842  0.605941    0.605941    0.605941 -0.000030  ... -0.000011
# 4  1212.342760  0.599630    0.599630    0.599630  0.000271  ... -0.000045
#
#    weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 0      0.000087      0.000087 -0.001073     -0.001073     -0.001073
# 1      0.000055      0.000055 -0.001071     -0.001071     -0.001071
# 2      0.000022      0.000022 -0.001069     -0.001069     -0.001069
# 3     -0.000011     -0.000011 -0.001067     -0.001067     -0.001067
# 4     -0.000045     -0.000045 -0.001065     -0.001065     -0.001065
#
#    additive_terms  additive_terms_lower  additive_terms_upper         yhat
# 0             0.0                   0.0                   0.0  1956.157995
# 1             0.0                   0.0                   0.0  1944.797776
# 2             0.0                   0.0                   0.0  1952.871410
# 3             0.0                   0.0                   0.0  1945.616344
# 4             0.0                   0.0                   0.0  1938.282809
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(test_df['ds'], test_df['ETH_price'].values.reshape(-1, 1),label='Real Data')
ax.plot(forecast_insample['ds'], forecast_insample['yhat'].values.reshape(-1, 1),label='Predict Data',color='red')
# ax.plot(test_df.index, prices)
ax.legend()
ax.set(title=f"{our_choices[0]}'s price in test dataset",
       xlabel='Time',
       ylabel='Price ($)');

# %%
#plot the predict and real data in the graph, and residual plot,compare the models and choose the best one MAE)
import numpy as np
import matplotlib.pyplot as plt

bars = overall.keys()

x = np.arange(len(bars))

plt.xticks(x, bars, fontweight='bold', horizontalalignment='right')

# a = [overall[i]['train']['mae'] for i in bars]
b = [overall[i]['test']['mae'] for i in bars]

total_width, n = 0.8, 4
width = total_width / n
x = x - (total_width - width) / 3

# plt.bar(x, a,  width=width, label='Testing MAE')
plt.bar(x , b, label='Testing MAE')
plt.legend()
plt.show()

# %%
# extra unsupervised learning --Nilaksh--Aider
