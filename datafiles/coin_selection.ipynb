# %% [markdown]
# # Load rankings and categories

# %%
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json,os,pdb
import tqdm
import warnings

# %% [markdown]
# # Choose the universe
#
# Select the number of coins to consider. Right now we are still using a market cap criteria

# %%
N = 50

# %% [markdown]
# # Load data

# %%
df = pd.read_parquet('/content/gdrive/datafiles/daily_20221004.parquet.gzi') # modify the path according to your needs
df.columns = [c.split('.')[-1].replace('_','') for c in df.columns]
df.index = df.index.set_levels([df.index.levels[0], pd.to_datetime(df.index.levels[1])])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-eb9f74226176> in <module>
# ----> 1 df = pd.read_parquet('/content/gdrive/datafiles/daily_20221004.parquet.gzi') # modify the path according to your needs
#       2 df.columns = [c.split('.')[-1].replace('_','') for c in df.columns]
#       3 df.index = df.index.set_levels([df.index.levels[0], pd.to_datetime(df.index.levels[1])])
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     234             kwargs.pop("filesystem", None),
#     235             storage_options=storage_options,
# --> 236             mode="rb",
#     237         )
#     238         try:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     100         # this branch is used for example when reading from non-fsspec URLs
#     101         handles = get_handle(
# --> 102             path_or_handle, mode, is_text=False, storage_options=storage_options
#     103         )
#     104         fs = None
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/datafiles/daily_20221004.parquet.gzi'

# %% [markdown]
# Load the listing file and check for the rankings

# %%
with open('output/listingmaps/listing_map_20221004.json',encoding='utf-8') as json_data:
    data = json.load(json_data)
listmap = pd.DataFrame(data['data'])
listmap.sort_values('cmc_rank',inplace=True)
listmap.set_index('cmc_rank',inplace=True)
listmap['symbol_id'] = listmap['symbol']+ '_'+ listmap['id'].astype(str)

# %% [markdown]
# # Filter by the universe
# Select only the symbols that interest you. According to our previous choice of N, in this case we are filtering for the top 50 by market cap

# %%
symbols = list(listmap.loc[:N,'symbol_id'].values)

# %% [markdown]
# Remove stablecoins by using the category JSON (available in sakai as the listing file)

# %%
with open('output/categories/category_stablecoin.json',encoding='utf-8') as json_data:
    data = json.load(json_data)
stable_df = pd.json_normalize(data['data']['coins'],max_level=5)
stable_df['symbol_id'] = stable_df['symbol'] + '_' + stable_df['id'].astype(str)
stablecoins = list(stable_df['symbol_id'].values)

# %%
# get the top 200 by mkt cap
symbols = set(listmap.loc[:N,'symbol_id'].values) - set(stablecoins)

for l in stablecoins:
    if l in symbols:
        print('Stablecoins in the list!')
